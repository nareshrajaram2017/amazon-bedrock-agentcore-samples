# %%
# %pip install -r lab_helpers/lab5_frontend/requirements.txt -q

# %% [markdown]
# ## Run Streamlit App

# %%
#Get SageMaker URL for the Streamlit APP
from lab_helpers.lab5_frontend.sagemaker_helper import get_streamlit_url
streamlit_url = get_streamlit_url()
print(f'\n 🚀 Click here to access your streamlit application: \n {streamlit_url} \n')

# !cd lab_helpers/lab5_frontend/ && pwd && streamlit run main.py --server.port 8501
